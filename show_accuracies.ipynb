# %%
import torch
import numpy as np

layer2 = np.zeros((0, 10))  # Initialize an empty array with shape (0, 10)

for index in range(10):
    # Correct way to concatenate strings
    filename = 'training_activities2_{}_9.npy'.format(index)
    
    # Load the data from the file
    layer2_new = np.load(filename)
    
    # Use np.vstack or np.concatenate to stack arrays vertically
    layer2 = np.vstack((layer2, layer2_new))

# If you want to concatenate along a different axis, you can use np.concatenate
# layer2 = np.concatenate((layer2, layer2_new), axis=0)
import torch
import numpy as np

layer3 = np.zeros((0, 10))  # Initialize an empty array with shape (0, 10)

for index in range(10):
    # Correct way to concatenate strings
    filename = 'training_activities3_{}_9.npy'.format(index)
    
    # Load the data from the file
    layer3_new = np.load(filename)
    
    # Use np.vstack or np.concatenate to stack arrays vertically
    layer3 = np.vstack((layer3, layer3_new))

# If you want to concatenate along a different axis, you can use np.concatenate
# layer2 = np.concatenate((layer2, layer2_new), axis=0)
import torch
import numpy as np

layer4 = np.zeros((0, 10))  # Initialize an empty array with shape (0, 10)

for index in range(10):
    # Correct way to concatenate strings
    filename = 'training_activities4_{}_9.npy'.format(index)
    
    # Load the data from the file
    layer4_new = np.load(filename)
    
    # Use np.vstack or np.concatenate to stack arrays vertically
    layer4 = np.vstack((layer4, layer4_new))

# If you want to concatenate along a different axis, you can use np.concatenate
# layer2 = np.concatenate((layer2, layer2_new), axis=0)

import torch
import numpy as np

layer5 = np.zeros((0, 10))  # Initialize an empty array with shape (0, 10)

for index in range(10):
    # Correct way to concatenate strings
    filename = 'training_activities5_{}_9.npy'.format(index)
    
    # Load the data from the file
    layer5_new = np.load(filename)
    
    # Use np.vstack or np.concatenate to stack arrays vertically
    layer5 = np.vstack((layer5, layer5_new))

# If you want to concatenate along a different axis, you can use np.concatenate
# layer2 = np.concatenate((layer2, layer2_new), axis=0)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

rainbow = sns.color_palette("magma", 4)

fig, ax = plt.subplots() 

layer2_err = np.std(layer2, axis=0)
layer2_mean = np.mean(layer2, axis=0)

#ax.plot(range(1, 11), layer1, color=rainbow[6], linewidth=4)
ax.plot(range(1, 11), layer2_mean, color=rainbow[0], linewidth=4)

ax.fill_between(range(1, 11), layer2_mean - layer2_err, layer2_mean + layer2_err,
                 color=rainbow[0], alpha=0.5, edgecolor = 'none')

layer3_err = np.std(layer3, axis=0)
layer3_mean = np.mean(layer3, axis=0)

#ax.plot(range(1, 11), layer1, color=rainbow[6], linewidth=4)
ax.plot(range(1, 11), layer3_mean, color=rainbow[1], linewidth=4)

ax.fill_between(range(1, 11), layer3_mean - layer3_err, layer3_mean + layer3_err,
                 color=rainbow[1], alpha=0.5, edgecolor = 'none')


layer4_err = np.std(layer4, axis=0)
layer4_mean = np.mean(layer4, axis=0)

#ax.plot(range(1, 11), layer1, color=rainbow[6], linewidth=4)
ax.plot(range(1, 11), layer4_mean, color=rainbow[2], linewidth=4)

ax.fill_between(range(1, 11), layer4_mean - layer4_err, layer4_mean + layer4_err,
                 color=rainbow[2], alpha=0.5, edgecolor = 'none')


layer5_err = np.std(layer5, axis=0)
layer5_mean = np.mean(layer5, axis=0)

#ax.plot(range(1, 11), layer1, color=rainbow[6], linewidth=4)
ax.plot(range(1, 11), layer5_mean, color=rainbow[3], linewidth=4)

ax.fill_between(range(1, 11), layer5_mean - layer5_err, layer5_mean + layer5_err,
                 color=rainbow[3], alpha=0.5, edgecolor = 'none')



ax.set_xlabel('Epoch', fontname="Arial", fontsize=20)
ax.set_ylabel('Accuracy', fontname="Arial", fontsize=20)
ax.set_title('Training Accuracy', fontname="Arial", fontsize=25, fontweight="bold")

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Set the font name for axis tick labels to be Arial
for tick in ax.get_xticklabels():
    tick.set_fontname("arial")
    tick.set_fontsize(20)
for tick in ax.get_yticklabels():
    tick.set_fontname("arial")
    tick.set_fontsize(20)

plt.ylim(.4, .7)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Example arrays: shape (10 models, 10 epochs)
# Replace with your actual `layer2`, `layer3`, `layer4`, `layer5` arrays
# layer2 = np.random.rand(10, 10) * 0.1 + 0.5  # shape: (10, 10)
# layer3 = np.random.rand(10, 10) * 0.1 + 0.52
# layer4 = np.random.rand(10, 10) * 0.1 + 0.55
# layer5 = np.random.rand(10, 10) * 0.1 + 0.57

rainbow = sns.color_palette("magma", 4)
fig, ax = plt.subplots(figsize=(5, 4))

# Plot individual curves for each model in each layer
for model_idx in range(layer2.shape[0]):
    ax.plot(range(1, 11), layer2[model_idx], color=rainbow[0], alpha=0.5, linewidth=2)

for model_idx in range(layer3.shape[0]):
    ax.plot(range(1, 11), layer3[model_idx], color=rainbow[1], alpha=0.5, linewidth=2)

for model_idx in range(layer4.shape[0]):
    ax.plot(range(1, 11), layer4[model_idx], color=rainbow[2], alpha=0.5, linewidth=2)

for model_idx in range(layer5.shape[0]):
    ax.plot(range(1, 11), layer5[model_idx], color=rainbow[3], alpha=0.5, linewidth=2)

# Labels and formatting
ax.set_xlabel('Epoch', fontname="Arial", fontsize=20)
ax.set_ylabel('Accuracy', fontname="Arial", fontsize=20)
ax.set_title('Training accuracy', fontname="Arial", fontsize=20, fontweight="bold")

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Set the font name for axis tick labels to be Arial
for tick in ax.get_xticklabels():
    tick.set_fontname("arial")
    tick.set_fontsize(20)
for tick in ax.get_yticklabels():
    tick.set_fontname("arial")
    tick.set_fontsize(20)

plt.ylim(0.4, 0.7)
plt.tight_layout()
plt.show()

# %%
import torch
import numpy as np

layer2 = np.zeros((0, 10))  # Initialize an empty array with shape (0, 10)

for index in range(10):
    # Correct way to concatenate strings
    filename = 'testing_activities2_{}_9.npy'.format(index)
    
    # Load the data from the file
    layer2_new = np.load(filename)
    
    # Use np.vstack or np.concatenate to stack arrays vertically
    layer2 = np.vstack((layer2, layer2_new))

# If you want to concatenate along a different axis, you can use np.concatenate
# layer2 = np.concatenate((layer2, layer2_new), axis=0)
import torch
import numpy as np

layer3 = np.zeros((0, 10))  # Initialize an empty array with shape (0, 10)

for index in range(10):
    # Correct way to concatenate strings
    filename = 'testing_activities3_{}_9.npy'.format(index)
    
    # Load the data from the file
    layer3_new = np.load(filename)
    
    # Use np.vstack or np.concatenate to stack arrays vertically
    layer3 = np.vstack((layer3, layer3_new))

# If you want to concatenate along a different axis, you can use np.concatenate
# layer2 = np.concatenate((layer2, layer2_new), axis=0)
import torch
import numpy as np

layer4 = np.zeros((0, 10))  # Initialize an empty array with shape (0, 10)

for index in range(10):
    # Correct way to concatenate strings
    filename = 'testing_activities4_{}_9.npy'.format(index)
    
    # Load the data from the file
    layer4_new = np.load(filename)
    
    # Use np.vstack or np.concatenate to stack arrays vertically
    layer4 = np.vstack((layer4, layer4_new))

# If you want to concatenate along a different axis, you can use np.concatenate
# layer2 = np.concatenate((layer2, layer2_new), axis=0)

import torch
import numpy as np

layer5 = np.zeros((0, 10))  # Initialize an empty array with shape (0, 10)

for index in range(10):
    # Correct way to concatenate strings
    filename = 'testing_activities5_{}_9.npy'.format(index)
    
    # Load the data from the file
    layer5_new = np.load(filename)
    
    # Use np.vstack or np.concatenate to stack arrays vertically
    layer5 = np.vstack((layer5, layer5_new))

# If you want to concatenate along a different axis, you can use np.concatenate
# layer2 = np.concatenate((layer2, layer2_new), axis=0)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

rainbow = sns.color_palette("magma", 4)

fig, ax = plt.subplots() 

layer2_err = np.std(layer2, axis=0)
layer2_mean = np.mean(layer2, axis=0)

#ax.plot(range(1, 11), layer1, color=rainbow[6], linewidth=4)
ax.plot(range(1, 11), layer2_mean, color=rainbow[0], linewidth=4)

ax.fill_between(range(1, 11), layer2_mean - layer2_err, layer2_mean + layer2_err,
                 color=rainbow[0], alpha=0.5, edgecolor = 'none')

layer3_err = np.std(layer3, axis=0)
layer3_mean = np.mean(layer3, axis=0)

#ax.plot(range(1, 11), layer1, color=rainbow[6], linewidth=4)
ax.plot(range(1, 11), layer3_mean, color=rainbow[1], linewidth=4)

ax.fill_between(range(1, 11), layer3_mean - layer3_err, layer3_mean + layer3_err,
                 color=rainbow[1], alpha=0.5, edgecolor = 'none')


layer4_err = np.std(layer4, axis=0)
layer4_mean = np.mean(layer4, axis=0)

#ax.plot(range(1, 11), layer1, color=rainbow[6], linewidth=4)
ax.plot(range(1, 11), layer4_mean, color=rainbow[2], linewidth=4)

ax.fill_between(range(1, 11), layer4_mean - layer4_err, layer4_mean + layer4_err,
                 color=rainbow[2], alpha=0.5, edgecolor = 'none')


layer5_err = np.std(layer5, axis=0)
layer5_mean = np.mean(layer5, axis=0)

#ax.plot(range(1, 11), layer1, color=rainbow[6], linewidth=4)
ax.plot(range(1, 11), layer5_mean, color=rainbow[3], linewidth=4)

ax.fill_between(range(1, 11), layer5_mean - layer5_err, layer5_mean + layer5_err,
                 color=rainbow[3], alpha=0.5, edgecolor = 'none')



ax.set_xlabel('Epoch', fontname="Arial", fontsize=20)
ax.set_ylabel('Accuracy', fontname="Arial", fontsize=20)
ax.set_title('Testing Accuracy', fontname="Arial", fontsize=25, fontweight="bold")

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Set the font name for axis tick labels to be Arial
for tick in ax.get_xticklabels():
    tick.set_fontname("arial")
    tick.set_fontsize(20)
for tick in ax.get_yticklabels():
    tick.set_fontname("arial")
    tick.set_fontsize(20)

plt.ylim(.4, .7)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Example arrays: shape (10 models, 10 epochs)
# Replace with your actual `layer2`, `layer3`, `layer4`, `layer5` arrays
# layer2 = np.random.rand(10, 10) * 0.1 + 0.5  # shape: (10, 10)
# layer3 = np.random.rand(10, 10) * 0.1 + 0.52
# layer4 = np.random.rand(10, 10) * 0.1 + 0.55
# layer5 = np.random.rand(10, 10) * 0.1 + 0.57

rainbow = sns.color_palette("magma", 4)
fig, ax = plt.subplots(figsize=(5, 4))

# Plot individual curves for each model in each layer
for model_idx in range(layer2.shape[0]):
    ax.plot(range(1, 11), layer2[model_idx], color=rainbow[0], alpha=0.5, linewidth=2)

for model_idx in range(layer3.shape[0]):
    ax.plot(range(1, 11), layer3[model_idx], color=rainbow[1], alpha=0.5, linewidth=2)

for model_idx in range(layer4.shape[0]):
    ax.plot(range(1, 11), layer4[model_idx], color=rainbow[2], alpha=0.5, linewidth=2)

for model_idx in range(layer5.shape[0]):
    ax.plot(range(1, 11), layer5[model_idx], color=rainbow[3], alpha=0.5, linewidth=2)

# Labels and formatting
ax.set_xlabel('Epoch', fontname="Arial", fontsize=20)
ax.set_ylabel('Accuracy', fontname="Arial", fontsize=20)
ax.set_title('Test accuracy', fontname="Arial", fontsize=20, fontweight="bold")

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Set the font name for axis tick labels to be Arial
for tick in ax.get_xticklabels():
    tick.set_fontname("arial")
    tick.set_fontsize(20)
for tick in ax.get_yticklabels():
    tick.set_fontname("arial")
    tick.set_fontsize(20)

plt.ylim(0.4, 0.7)
plt.tight_layout()
plt.show()
