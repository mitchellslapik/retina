# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import numpy as np

# Define LeNet-5 model without dropout for color images
class LeNet5Color(nn.Module):
    def __init__(self):
        super(LeNet5Color, self).__init__()
        self.conv1 = nn.Conv2d(3, 6, kernel_size=5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, kernel_size=5)
        self.fc1 = nn.Linear(16 * 5 * 5, 120)
        self.fc2 = nn.Linear(120, 10)
        #self.fc3 = nn.Linear(84, 10)

    def forward(self, x):
        x = self.pool(torch.relu(self.conv1(x)))
        x = self.pool(torch.relu(self.conv2(x)))
        x = x.view(-1, 16 * 5 * 5)
        x = torch.relu(self.fc1(x))
        x = self.fc2(x)
        #x = self.fc3(x)
        return x


# Custom hook to register activations for all layers
class ActivationHook:
    def __init__(self):
        self.activations = []

    def __call__(self, module, input, output):
        self.activations.append(output.cpu().detach().numpy())

# Load CIFAR-10 dataset for color images
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])
trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=4, shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=4, shuffle=False, num_workers=2)

# Initialize LeNet-5 model for color images outside the training loop

# Loss function
criterion_color = nn.CrossEntropyLoss()

all_activation_patterns_list = []

# Train the model for color images
for training_iteration in range(10):  # Train the model 10 times
    
    net_color = LeNet5Color()

    optimizer_color = optim.Adam(net_color.parameters(), lr=0.001, weight_decay=0.001)

    # Register hooks for activation patterns for all layers
    activation_hooks = [ActivationHook() for _ in range(len(list(net_color.children())))]
    hook_handles = [layer.register_forward_hook(activation_hook) for layer, activation_hook in zip(net_color.children(), activation_hooks)]

    # Lists to store training and testing accuracies for each epoch
    training_accuracies = []
    testing_accuracies = []

    # Lists to store activation patterns for each layer
    activation_patterns_lists = [[] for _ in range(len(activation_hooks))]

    for epoch in range(10):  # Change the number of epochs as needed
        running_loss = 0.0
        correct_train = 0
        total_train = 0

        for i, data in enumerate(trainloader, 0):
            inputs, labels = data
            optimizer_color.zero_grad()
            outputs = net_color(inputs)
            loss = criterion_color(outputs, labels)
            loss.backward()
            optimizer_color.step()
            running_loss += loss.item()

            _, predicted = torch.max(outputs.data, 1)
            total_train += labels.size(0)
            correct_train += (predicted == labels).sum().item()
            
            if epoch == 9:

                # Save activation patterns for each layer
                for j, activation_hook in enumerate(activation_hooks):
                    activation_patterns_lists[j].append(activation_hook.activations)

        train_accuracy = correct_train / total_train
        training_accuracies.append(train_accuracy)

        train_loss = running_loss / len(trainloader)
        print(f'Training Iteration {training_iteration + 1}, Epoch {epoch + 1}/{10}, Training Loss: {train_loss:.4f}, Training Accuracy: {train_accuracy:.4f}')

        # Test the model for color images
        correct_test = 0
        total_test = 0
        test_loss = 0.0

        with torch.no_grad():
            for data in testloader:
                inputs, labels = data
                outputs = net_color(inputs)
                loss = criterion_color(outputs, labels)
                test_loss += loss.item()

                _, predicted = torch.max(outputs.data, 1)
                total_test += labels.size(0)
                correct_test += (predicted == labels).sum().item()

        test_accuracy = correct_test / total_test
        testing_accuracies.append(test_accuracy)

        test_loss /= len(testloader)
        print(f'Testing Loss: {test_loss:.4f}, Testing Accuracy: {test_accuracy:.4f}')

    # Save activation patterns for each layer for each run
    #for j, activation_patterns in enumerate(activation_patterns_lists):
    #    activation_filename = f'activations4_{training_iteration}_{epoch}_layer{j}.npy'
    #    np.save(activation_filename, np.array(activation_patterns))

    # Save the model for each run
    model_filename = f'model4_{training_iteration}_{epoch}.pth'
    torch.save(net_color.state_dict(), model_filename)

    # Save training and testing activities for each run
    training_filename = f'training_activities4_{training_iteration}_{epoch}.npy'
    testing_filename = f'testing_activities4_{training_iteration}_{epoch}.npy'

    np.save(training_filename, np.array(training_accuracies))
    np.save(testing_filename, np.array(testing_accuracies))

    # Remove the hooks after each epoch
    for handle in hook_handles:
        handle.remove()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Training Iteration 1, Epoch 1/10, Training Loss: 1.5276, Training Accuracy: 0.4442
# Testing Loss: 1.3486, Testing Accuracy: 0.5144
# Training Iteration 1, Epoch 2/10, Training Loss: 1.2964, Training Accuracy: 0.5358
# Testing Loss: 1.2776, Testing Accuracy: 0.5386
# Training Iteration 1, Epoch 3/10, Training Loss: 1.2114, Training Accuracy: 0.5677
# Testing Loss: 1.2516, Testing Accuracy: 0.5563
# Training Iteration 1, Epoch 4/10, Training Loss: 1.1580, Training Accuracy: 0.5885
# Testing Loss: 1.2545, Testing Accuracy: 0.5703
# Training Iteration 1, Epoch 5/10, Training Loss: 1.1264, Training Accuracy: 0.6029
# Testing Loss: 1.1534, Testing Accuracy: 0.6000
# Training Iteration 1, Epoch 6/10, Training Loss: 1.0983, Training Accuracy: 0.6120
# Testing Loss: 1.1439, Testing Accuracy: 0.6048
# Training Iteration 1, Epoch 7/10, Training Loss: 1.0787, Training Accuracy: 0.6192
# Testing Loss: 1.1763, Testing Accuracy: 0.5868
# Training Iteration 1, Epoch 8/10, Training Loss: 1.0621, Training Accuracy: 0.6269
# Testing Loss: 1.1442, Testing Accuracy: 0.5941
# Training Iteration 1, Epoch 9/10, Training Loss: 1.0452, Training Accuracy: 0.6326
# Testing Loss: 1.1841, Testing Accuracy: 0.5882
# Training Iteration 1, Epoch 10/10, Training Loss: 1.0353, Training Accuracy: 0.6342
# Testing Loss: 1.0817, Testing Accuracy: 0.6231
# Training Iteration 2, Epoch 1/10, Training Loss: 1.4903, Training Accuracy: 0.4594
# Testing Loss: 1.2904, Testing Accuracy: 0.5402
# Training Iteration 2, Epoch 2/10, Training Loss: 1.2653, Training Accuracy: 0.5464
# Testing Loss: 1.2742, Testing Accuracy: 0.5405
# Training Iteration 2, Epoch 3/10, Training Loss: 1.1845, Training Accuracy: 0.5768
# Testing Loss: 1.2204, Testing Accuracy: 0.5641
# Training Iteration 2, Epoch 4/10, Training Loss: 1.1347, Training Accuracy: 0.5971
# Testing Loss: 1.1641, Testing Accuracy: 0.5918
# Training Iteration 2, Epoch 5/10, Training Loss: 1.0949, Training Accuracy: 0.6121
# Testing Loss: 1.1069, Testing Accuracy: 0.6090
# Training Iteration 2, Epoch 6/10, Training Loss: 1.0624, Training Accuracy: 0.6221
# Testing Loss: 1.1104, Testing Accuracy: 0.6078
# Training Iteration 2, Epoch 7/10, Training Loss: 1.0414, Training Accuracy: 0.6333
# Testing Loss: 1.1170, Testing Accuracy: 0.6095
# Training Iteration 2, Epoch 8/10, Training Loss: 1.0262, Training Accuracy: 0.6371
# Testing Loss: 1.0851, Testing Accuracy: 0.6207
# Training Iteration 2, Epoch 9/10, Training Loss: 1.0147, Training Accuracy: 0.6413
# Testing Loss: 1.0795, Testing Accuracy: 0.6229
# Training Iteration 2, Epoch 10/10, Training Loss: 1.0026, Training Accuracy: 0.6457
# Testing Loss: 1.0854, Testing Accuracy: 0.6225
# Training Iteration 3, Epoch 1/10, Training Loss: 1.4813, Training Accuracy: 0.4616
# Testing Loss: 1.2958, Testing Accuracy: 0.5334
# Training Iteration 3, Epoch 2/10, Training Loss: 1.2461, Training Accuracy: 0.5563
# Testing Loss: 1.2281, Testing Accuracy: 0.5707
# Training Iteration 3, Epoch 3/10, Training Loss: 1.1605, Training Accuracy: 0.5876
# Testing Loss: 1.1451, Testing Accuracy: 0.5946
# Training Iteration 3, Epoch 4/10, Training Loss: 1.1159, Training Accuracy: 0.6046
# Testing Loss: 1.1559, Testing Accuracy: 0.5886
# Training Iteration 3, Epoch 5/10, Training Loss: 1.0862, Training Accuracy: 0.6149
# Testing Loss: 1.1422, Testing Accuracy: 0.6019
# Training Iteration 3, Epoch 6/10, Training Loss: 1.0620, Training Accuracy: 0.6265
# Testing Loss: 1.0866, Testing Accuracy: 0.6205
# Training Iteration 3, Epoch 7/10, Training Loss: 1.0407, Training Accuracy: 0.6337
# Testing Loss: 1.1125, Testing Accuracy: 0.6114
# Training Iteration 3, Epoch 8/10, Training Loss: 1.0311, Training Accuracy: 0.6388
# Testing Loss: 1.0944, Testing Accuracy: 0.6182
# Training Iteration 3, Epoch 9/10, Training Loss: 1.0188, Training Accuracy: 0.6404
# Testing Loss: 1.1118, Testing Accuracy: 0.6169
# Training Iteration 3, Epoch 10/10, Training Loss: 1.0080, Training Accuracy: 0.6444
# Testing Loss: 1.0905, Testing Accuracy: 0.6138
# Training Iteration 4, Epoch 1/10, Training Loss: 1.5411, Training Accuracy: 0.4359
# Testing Loss: 1.3613, Testing Accuracy: 0.5147
# Training Iteration 4, Epoch 2/10, Training Loss: 1.3041, Training Accuracy: 0.5321
# Testing Loss: 1.2902, Testing Accuracy: 0.5336
# Training Iteration 4, Epoch 3/10, Training Loss: 1.2080, Training Accuracy: 0.5691
# Testing Loss: 1.2001, Testing Accuracy: 0.5803
# Training Iteration 4, Epoch 4/10, Training Loss: 1.1485, Training Accuracy: 0.5928
# Testing Loss: 1.1662, Testing Accuracy: 0.5927
# Training Iteration 4, Epoch 5/10, Training Loss: 1.1079, Training Accuracy: 0.6095
# Testing Loss: 1.1469, Testing Accuracy: 0.6000
# Training Iteration 4, Epoch 6/10, Training Loss: 1.0756, Training Accuracy: 0.6222
# Testing Loss: 1.1369, Testing Accuracy: 0.6132
# Training Iteration 4, Epoch 7/10, Training Loss: 1.0552, Training Accuracy: 0.6295
# Testing Loss: 1.0810, Testing Accuracy: 0.6230
# Training Iteration 4, Epoch 8/10, Training Loss: 1.0431, Training Accuracy: 0.6346
# Testing Loss: 1.1379, Testing Accuracy: 0.6025
# Training Iteration 4, Epoch 9/10, Training Loss: 1.0321, Training Accuracy: 0.6380
# Testing Loss: 1.0917, Testing Accuracy: 0.6219
# Training Iteration 4, Epoch 10/10, Training Loss: 1.0199, Training Accuracy: 0.6445
# Testing Loss: 1.0496, Testing Accuracy: 0.6337
# Training Iteration 5, Epoch 1/10, Training Loss: 1.5095, Training Accuracy: 0.4500
# Testing Loss: 1.2936, Testing Accuracy: 0.5337
# Training Iteration 5, Epoch 2/10, Training Loss: 1.2736, Training Accuracy: 0.5451
# Testing Loss: 1.2190, Testing Accuracy: 0.5682
# Training Iteration 5, Epoch 3/10, Training Loss: 1.1950, Training Accuracy: 0.5745
# Testing Loss: 1.2050, Testing Accuracy: 0.5721
# Training Iteration 5, Epoch 4/10, Training Loss: 1.1465, Training Accuracy: 0.5954
# Testing Loss: 1.1504, Testing Accuracy: 0.5944
# Training Iteration 5, Epoch 5/10, Training Loss: 1.1110, Training Accuracy: 0.6077
# Testing Loss: 1.1392, Testing Accuracy: 0.5945
# Training Iteration 5, Epoch 6/10, Training Loss: 1.0866, Training Accuracy: 0.6148
# Testing Loss: 1.1402, Testing Accuracy: 0.5910
# Training Iteration 5, Epoch 7/10, Training Loss: 1.0667, Training Accuracy: 0.6248
# Testing Loss: 1.1185, Testing Accuracy: 0.6074
# Training Iteration 5, Epoch 8/10, Training Loss: 1.0492, Training Accuracy: 0.6310
# Testing Loss: 1.0766, Testing Accuracy: 0.6233
# Training Iteration 5, Epoch 9/10, Training Loss: 1.0377, Training Accuracy: 0.6359
# Testing Loss: 1.1391, Testing Accuracy: 0.6017
# Training Iteration 5, Epoch 10/10, Training Loss: 1.0255, Training Accuracy: 0.6391
# Testing Loss: 1.1132, Testing Accuracy: 0.6150
# Training Iteration 6, Epoch 1/10, Training Loss: 1.4918, Training Accuracy: 0.4602
# Testing Loss: 1.3687, Testing Accuracy: 0.5117
# Training Iteration 6, Epoch 2/10, Training Loss: 1.2649, Training Accuracy: 0.5487
# Testing Loss: 1.2052, Testing Accuracy: 0.5740
# Training Iteration 6, Epoch 3/10, Training Loss: 1.1758, Training Accuracy: 0.5811
# Testing Loss: 1.2192, Testing Accuracy: 0.5647
# Training Iteration 6, Epoch 4/10, Training Loss: 1.1119, Training Accuracy: 0.6044
# Testing Loss: 1.1415, Testing Accuracy: 0.5970
# Training Iteration 6, Epoch 5/10, Training Loss: 1.0680, Training Accuracy: 0.6242
# Testing Loss: 1.1105, Testing Accuracy: 0.6088
# Training Iteration 6, Epoch 6/10, Training Loss: 1.0379, Training Accuracy: 0.6369
# Testing Loss: 1.1398, Testing Accuracy: 0.6024
# Training Iteration 6, Epoch 7/10, Training Loss: 1.0183, Training Accuracy: 0.6405
# Testing Loss: 1.0818, Testing Accuracy: 0.6191
# Training Iteration 6, Epoch 8/10, Training Loss: 0.9991, Training Accuracy: 0.6497
# Testing Loss: 1.0322, Testing Accuracy: 0.6378
# Training Iteration 6, Epoch 9/10, Training Loss: 0.9868, Training Accuracy: 0.6546
# Testing Loss: 1.1011, Testing Accuracy: 0.6178
# Training Iteration 6, Epoch 10/10, Training Loss: 0.9770, Training Accuracy: 0.6579
# Testing Loss: 1.0242, Testing Accuracy: 0.6462
# Training Iteration 7, Epoch 1/10, Training Loss: 1.5179, Training Accuracy: 0.4459
# Testing Loss: 1.3566, Testing Accuracy: 0.5120
# Training Iteration 7, Epoch 2/10, Training Loss: 1.2742, Training Accuracy: 0.5435
# Testing Loss: 1.2165, Testing Accuracy: 0.5716
# Training Iteration 7, Epoch 3/10, Training Loss: 1.1829, Training Accuracy: 0.5836
# Testing Loss: 1.1680, Testing Accuracy: 0.5789
# Training Iteration 7, Epoch 4/10, Training Loss: 1.1250, Training Accuracy: 0.6031
# Testing Loss: 1.1196, Testing Accuracy: 0.6086
# Training Iteration 7, Epoch 5/10, Training Loss: 1.0708, Training Accuracy: 0.6218
# Testing Loss: 1.1646, Testing Accuracy: 0.5952
# Training Iteration 7, Epoch 6/10, Training Loss: 1.0378, Training Accuracy: 0.6375
# Testing Loss: 1.1229, Testing Accuracy: 0.6088
# Training Iteration 7, Epoch 7/10, Training Loss: 1.0177, Training Accuracy: 0.6434
# Testing Loss: 1.1770, Testing Accuracy: 0.6034
# Training Iteration 7, Epoch 8/10, Training Loss: 1.0071, Training Accuracy: 0.6489
# Testing Loss: 1.1094, Testing Accuracy: 0.6265
# Training Iteration 7, Epoch 9/10, Training Loss: 0.9974, Training Accuracy: 0.6529
# Testing Loss: 1.0419, Testing Accuracy: 0.6389
# Training Iteration 7, Epoch 10/10, Training Loss: 0.9846, Training Accuracy: 0.6565
# Testing Loss: 1.0852, Testing Accuracy: 0.6314
# Training Iteration 8, Epoch 1/10, Training Loss: 1.5181, Training Accuracy: 0.4466
# Testing Loss: 1.3520, Testing Accuracy: 0.5221
# Training Iteration 8, Epoch 2/10, Training Loss: 1.2781, Training Accuracy: 0.5448
# Testing Loss: 1.2005, Testing Accuracy: 0.5732
# Training Iteration 8, Epoch 3/10, Training Loss: 1.1867, Training Accuracy: 0.5774
# Testing Loss: 1.1847, Testing Accuracy: 0.5779
# Training Iteration 8, Epoch 4/10, Training Loss: 1.1330, Training Accuracy: 0.6013
# Testing Loss: 1.1323, Testing Accuracy: 0.5993
# Training Iteration 8, Epoch 5/10, Training Loss: 1.0929, Training Accuracy: 0.6151
# Testing Loss: 1.1278, Testing Accuracy: 0.6023
# Training Iteration 8, Epoch 6/10, Training Loss: 1.0640, Training Accuracy: 0.6265
# Testing Loss: 1.0976, Testing Accuracy: 0.6146
# Training Iteration 8, Epoch 7/10, Training Loss: 1.0398, Training Accuracy: 0.6336
# Testing Loss: 1.0767, Testing Accuracy: 0.6236
# Training Iteration 8, Epoch 8/10, Training Loss: 1.0209, Training Accuracy: 0.6395
# Testing Loss: 1.0939, Testing Accuracy: 0.6139
# Training Iteration 8, Epoch 9/10, Training Loss: 1.0045, Training Accuracy: 0.6487
# Testing Loss: 1.0865, Testing Accuracy: 0.6259
# Training Iteration 8, Epoch 10/10, Training Loss: 0.9949, Training Accuracy: 0.6518
# Testing Loss: 1.0751, Testing Accuracy: 0.6260
# Training Iteration 9, Epoch 1/10, Training Loss: 1.4898, Training Accuracy: 0.4603
# Testing Loss: 1.3587, Testing Accuracy: 0.5185
# Training Iteration 9, Epoch 2/10, Training Loss: 1.2706, Training Accuracy: 0.5464
# Testing Loss: 1.2207, Testing Accuracy: 0.5613
# Training Iteration 9, Epoch 3/10, Training Loss: 1.1867, Training Accuracy: 0.5798
# Testing Loss: 1.1719, Testing Accuracy: 0.5785
# Training Iteration 9, Epoch 4/10, Training Loss: 1.1351, Training Accuracy: 0.5983
# Testing Loss: 1.1571, Testing Accuracy: 0.5940
# Training Iteration 9, Epoch 5/10, Training Loss: 1.0969, Training Accuracy: 0.6129
# Testing Loss: 1.1577, Testing Accuracy: 0.5911
# Training Iteration 9, Epoch 6/10, Training Loss: 1.0682, Training Accuracy: 0.6225
# Testing Loss: 1.0927, Testing Accuracy: 0.6160
# Training Iteration 9, Epoch 7/10, Training Loss: 1.0431, Training Accuracy: 0.6323
# Testing Loss: 1.1941, Testing Accuracy: 0.5849
# Training Iteration 9, Epoch 8/10, Training Loss: 1.0254, Training Accuracy: 0.6377
# Testing Loss: 1.1074, Testing Accuracy: 0.6086
# Training Iteration 9, Epoch 9/10, Training Loss: 1.0079, Training Accuracy: 0.6481
# Testing Loss: 1.0866, Testing Accuracy: 0.6194
# Training Iteration 9, Epoch 10/10, Training Loss: 0.9956, Training Accuracy: 0.6514
# Testing Loss: 1.0901, Testing Accuracy: 0.6194
# Training Iteration 10, Epoch 1/10, Training Loss: 1.5055, Training Accuracy: 0.4521
# Testing Loss: 1.4484, Testing Accuracy: 0.4850
# Training Iteration 10, Epoch 2/10, Training Loss: 1.2908, Training Accuracy: 0.5394
# Testing Loss: 1.2628, Testing Accuracy: 0.5523
# Training Iteration 10, Epoch 3/10, Training Loss: 1.2155, Training Accuracy: 0.5684
# Testing Loss: 1.2363, Testing Accuracy: 0.5601
# Training Iteration 10, Epoch 4/10, Training Loss: 1.1617, Training Accuracy: 0.5894
# Testing Loss: 1.2082, Testing Accuracy: 0.5767
# Training Iteration 10, Epoch 5/10, Training Loss: 1.1237, Training Accuracy: 0.6043
# Testing Loss: 1.1708, Testing Accuracy: 0.5964
# Training Iteration 10, Epoch 6/10, Training Loss: 1.0984, Training Accuracy: 0.6154
# Testing Loss: 1.1015, Testing Accuracy: 0.6204
# Training Iteration 10, Epoch 7/10, Training Loss: 1.0802, Training Accuracy: 0.6215
# Testing Loss: 1.1310, Testing Accuracy: 0.6078
# Training Iteration 10, Epoch 8/10, Training Loss: 1.0671, Training Accuracy: 0.6248
# Testing Loss: 1.1281, Testing Accuracy: 0.6085
# Training Iteration 10, Epoch 9/10, Training Loss: 1.0547, Training Accuracy: 0.6278
# Testing Loss: 1.0965, Testing Accuracy: 0.6198
# Training Iteration 10, Epoch 10/10, Training Loss: 1.0469, Training Accuracy: 0.6331
# Testing Loss: 1.1107, Testing Accuracy: 0.6124
