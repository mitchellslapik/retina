# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import numpy as np

# Define LeNet-5 model without dropout for color images
class LeNet5Color(nn.Module):
    def __init__(self):
        super(LeNet5Color, self).__init__()
        self.conv1 = nn.Conv2d(3, 6, kernel_size=5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, kernel_size=5)
        self.fc1 = nn.Linear(16 * 5 * 5, 10)

    def forward(self, x):
        x = self.pool(torch.relu(self.conv1(x)))
        x = self.pool(torch.relu(self.conv2(x)))
        x = x.view(-1, 16 * 5 * 5)
        x = self.fc1(x)
        return x

# Custom hook to register activations for conv1 layer only
class Conv1ActivationHook:
    def __init__(self):
        self.activations = []

    def __call__(self, module, input, output):
        self.activations.append(output.cpu().detach().numpy())

# Load CIFAR-10 dataset for color images
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])
trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=4, shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=4, shuffle=False, num_workers=2)

# Loss function
criterion_color = nn.CrossEntropyLoss()


# Train the model for color images
for training_iteration in range(10):  # Train the model 10 times

    net_color = LeNet5Color()

    optimizer_color = optim.Adam(net_color.parameters(), lr=0.001, weight_decay=0.001)

    # Register hook for activation patterns for conv1 layer only
    activation_hook = Conv1ActivationHook()
    hook_handle = net_color.conv1.register_forward_hook(activation_hook)

    # Lists to store training and testing accuracies for each epoch
    training_accuracies = []
    testing_accuracies = []

    for epoch in range(10):  # Change the number of epochs as needed
        running_loss = 0.0
        correct_train = 0
        total_train = 0

        for i, data in enumerate(trainloader, 0):
            inputs, labels = data
            optimizer_color.zero_grad()
            outputs = net_color(inputs)
            loss = criterion_color(outputs, labels)
            loss.backward()
            optimizer_color.step()
            running_loss += loss.item()

            _, predicted = torch.max(outputs.data, 1)
            total_train += labels.size(0)
            correct_train += (predicted == labels).sum().item()

        train_accuracy = correct_train / total_train
        training_accuracies.append(train_accuracy)

        train_loss = running_loss / len(trainloader)
        print(f'Training Iteration {training_iteration + 1}, Epoch {epoch + 1}/{10}, Training Loss: {train_loss:.4f}, Training Accuracy: {train_accuracy:.4f}')

        # Test the model for color images
        correct_test = 0
        total_test = 0
        test_loss = 0.0

        with torch.no_grad():
            for data in testloader:
                inputs, labels = data
                outputs = net_color(inputs)
                loss = criterion_color(outputs, labels)
                test_loss += loss.item()

                _, predicted = torch.max(outputs.data, 1)
                total_test += labels.size(0)
                correct_test += (predicted == labels).sum().item()

        test_accuracy = correct_test / total_test
        testing_accuracies.append(test_accuracy)

        test_loss /= len(testloader)
        print(f'Testing Loss: {test_loss:.4f}, Testing Accuracy: {test_accuracy:.4f}')

    # Save activation patterns for conv1 layer for each run
   # activation_filename = f'conv1_activations3_{training_iteration}_{epoch}.npy'
    #np.save(activation_filename, np.array(activation_hook.activations))

    # Save the model for each run
    model_filename = f'model3_{training_iteration}_{epoch}.pth'
    torch.save(net_color.state_dict(), model_filename)

    # Save training and testing activities for each run
    training_filename = f'training_activities3_{training_iteration}_{epoch}.npy'
    testing_filename = f'testing_activities3_{training_iteration}_{epoch}.npy'

    np.save(training_filename, np.array(training_accuracies))
    np.save(testing_filename, np.array(testing_accuracies))

    # Remove the hook after each epoch
    hook_handle.remove()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Training Iteration 1, Epoch 1/10, Training Loss: 1.5098, Training Accuracy: 0.4555
# Testing Loss: 1.3359, Testing Accuracy: 0.5213
# Training Iteration 1, Epoch 2/10, Training Loss: 1.3015, Training Accuracy: 0.5400
# Testing Loss: 1.2368, Testing Accuracy: 0.5625
# Training Iteration 1, Epoch 3/10, Training Loss: 1.2359, Training Accuracy: 0.5641
# Testing Loss: 1.1999, Testing Accuracy: 0.5779
# Training Iteration 1, Epoch 4/10, Training Loss: 1.2029, Training Accuracy: 0.5771
# Testing Loss: 1.1944, Testing Accuracy: 0.5843
# Training Iteration 1, Epoch 5/10, Training Loss: 1.1814, Training Accuracy: 0.5884
# Testing Loss: 1.2664, Testing Accuracy: 0.5606
# Training Iteration 1, Epoch 6/10, Training Loss: 1.1647, Training Accuracy: 0.5916
# Testing Loss: 1.1800, Testing Accuracy: 0.5867
# Training Iteration 1, Epoch 7/10, Training Loss: 1.1504, Training Accuracy: 0.5990
# Testing Loss: 1.2360, Testing Accuracy: 0.5646
# Training Iteration 1, Epoch 8/10, Training Loss: 1.1370, Training Accuracy: 0.6029
# Testing Loss: 1.1493, Testing Accuracy: 0.5970
# Training Iteration 1, Epoch 9/10, Training Loss: 1.1270, Training Accuracy: 0.6057
# Testing Loss: 1.1781, Testing Accuracy: 0.5872
# Training Iteration 1, Epoch 10/10, Training Loss: 1.1190, Training Accuracy: 0.6093
# Testing Loss: 1.1768, Testing Accuracy: 0.5915
# Training Iteration 2, Epoch 1/10, Training Loss: 1.5318, Training Accuracy: 0.4489
# Testing Loss: 1.3485, Testing Accuracy: 0.5180
# Training Iteration 2, Epoch 2/10, Training Loss: 1.3303, Training Accuracy: 0.5255
# Testing Loss: 1.3134, Testing Accuracy: 0.5403
# Training Iteration 2, Epoch 3/10, Training Loss: 1.2536, Training Accuracy: 0.5560
# Testing Loss: 1.2553, Testing Accuracy: 0.5609
# Training Iteration 2, Epoch 4/10, Training Loss: 1.2144, Training Accuracy: 0.5713
# Testing Loss: 1.1907, Testing Accuracy: 0.5850
# Training Iteration 2, Epoch 5/10, Training Loss: 1.1920, Training Accuracy: 0.5806
# Testing Loss: 1.1697, Testing Accuracy: 0.5874
# Training Iteration 2, Epoch 6/10, Training Loss: 1.1657, Training Accuracy: 0.5915
# Testing Loss: 1.1688, Testing Accuracy: 0.5874
# Training Iteration 2, Epoch 7/10, Training Loss: 1.1499, Training Accuracy: 0.5968
# Testing Loss: 1.1681, Testing Accuracy: 0.5879
# Training Iteration 2, Epoch 8/10, Training Loss: 1.1370, Training Accuracy: 0.6013
# Testing Loss: 1.1971, Testing Accuracy: 0.5827
# Training Iteration 2, Epoch 9/10, Training Loss: 1.1227, Training Accuracy: 0.6066
# Testing Loss: 1.1787, Testing Accuracy: 0.5848
# Training Iteration 2, Epoch 10/10, Training Loss: 1.1094, Training Accuracy: 0.6094
# Testing Loss: 1.1136, Testing Accuracy: 0.6070
# Training Iteration 3, Epoch 1/10, Training Loss: 1.5197, Training Accuracy: 0.4555
# Testing Loss: 1.3357, Testing Accuracy: 0.5194
# Training Iteration 3, Epoch 2/10, Training Loss: 1.2801, Training Accuracy: 0.5475
# Testing Loss: 1.2860, Testing Accuracy: 0.5427
# Training Iteration 3, Epoch 3/10, Training Loss: 1.2064, Training Accuracy: 0.5738
# Testing Loss: 1.1890, Testing Accuracy: 0.5765
# Training Iteration 3, Epoch 4/10, Training Loss: 1.1610, Training Accuracy: 0.5911
# Testing Loss: 1.1547, Testing Accuracy: 0.5966
# Training Iteration 3, Epoch 5/10, Training Loss: 1.1375, Training Accuracy: 0.5995
# Testing Loss: 1.1198, Testing Accuracy: 0.6057
# Training Iteration 3, Epoch 6/10, Training Loss: 1.1205, Training Accuracy: 0.6076
# Testing Loss: 1.1307, Testing Accuracy: 0.6056
# Training Iteration 3, Epoch 7/10, Training Loss: 1.1099, Training Accuracy: 0.6099
# Testing Loss: 1.1345, Testing Accuracy: 0.6055
# Training Iteration 3, Epoch 8/10, Training Loss: 1.0984, Training Accuracy: 0.6119
# Testing Loss: 1.1324, Testing Accuracy: 0.5986
# Training Iteration 3, Epoch 9/10, Training Loss: 1.0942, Training Accuracy: 0.6181
# Testing Loss: 1.1494, Testing Accuracy: 0.5968
# Training Iteration 3, Epoch 10/10, Training Loss: 1.0872, Training Accuracy: 0.6197
# Testing Loss: 1.1120, Testing Accuracy: 0.6123
# Training Iteration 4, Epoch 1/10, Training Loss: 1.4815, Training Accuracy: 0.4682
# Testing Loss: 1.3208, Testing Accuracy: 0.5275
# Training Iteration 4, Epoch 2/10, Training Loss: 1.2637, Training Accuracy: 0.5525
# Testing Loss: 1.2811, Testing Accuracy: 0.5365
# Training Iteration 4, Epoch 3/10, Training Loss: 1.2003, Training Accuracy: 0.5780
# Testing Loss: 1.1825, Testing Accuracy: 0.5881
# Training Iteration 4, Epoch 4/10, Training Loss: 1.1650, Training Accuracy: 0.5920
# Testing Loss: 1.1586, Testing Accuracy: 0.5979
# Training Iteration 4, Epoch 5/10, Training Loss: 1.1437, Training Accuracy: 0.6018
# Testing Loss: 1.2331, Testing Accuracy: 0.5699
# Training Iteration 4, Epoch 6/10, Training Loss: 1.1252, Training Accuracy: 0.6059
# Testing Loss: 1.1601, Testing Accuracy: 0.5920
# Training Iteration 4, Epoch 7/10, Training Loss: 1.1154, Training Accuracy: 0.6108
# Testing Loss: 1.1451, Testing Accuracy: 0.6016
# Training Iteration 4, Epoch 8/10, Training Loss: 1.1095, Training Accuracy: 0.6139
# Testing Loss: 1.1082, Testing Accuracy: 0.6172
# Training Iteration 4, Epoch 9/10, Training Loss: 1.0993, Training Accuracy: 0.6174
# Testing Loss: 1.0911, Testing Accuracy: 0.6239
# Training Iteration 4, Epoch 10/10, Training Loss: 1.0939, Training Accuracy: 0.6167
# Testing Loss: 1.1668, Testing Accuracy: 0.5965
# Training Iteration 5, Epoch 1/10, Training Loss: 1.4685, Training Accuracy: 0.4714
# Testing Loss: 1.2952, Testing Accuracy: 0.5392
# Training Iteration 5, Epoch 2/10, Training Loss: 1.2318, Training Accuracy: 0.5647
# Testing Loss: 1.1583, Testing Accuracy: 0.5920
# Training Iteration 5, Epoch 3/10, Training Loss: 1.1794, Training Accuracy: 0.5857
# Testing Loss: 1.1828, Testing Accuracy: 0.5833
# Training Iteration 5, Epoch 4/10, Training Loss: 1.1540, Training Accuracy: 0.5967
# Testing Loss: 1.1775, Testing Accuracy: 0.5843
# Training Iteration 5, Epoch 5/10, Training Loss: 1.1367, Training Accuracy: 0.6028
# Testing Loss: 1.1677, Testing Accuracy: 0.5905
# Training Iteration 5, Epoch 6/10, Training Loss: 1.1220, Training Accuracy: 0.6066
# Testing Loss: 1.1399, Testing Accuracy: 0.6016
# Training Iteration 5, Epoch 7/10, Training Loss: 1.1143, Training Accuracy: 0.6103
# Testing Loss: 1.1175, Testing Accuracy: 0.6040
# Training Iteration 5, Epoch 8/10, Training Loss: 1.1055, Training Accuracy: 0.6149
# Testing Loss: 1.1612, Testing Accuracy: 0.5893
# Training Iteration 5, Epoch 9/10, Training Loss: 1.0970, Training Accuracy: 0.6196
# Testing Loss: 1.1430, Testing Accuracy: 0.6059
# Training Iteration 5, Epoch 10/10, Training Loss: 1.0902, Training Accuracy: 0.6190
# Testing Loss: 1.1148, Testing Accuracy: 0.6063
# Training Iteration 6, Epoch 1/10, Training Loss: 1.5090, Training Accuracy: 0.4579
# Testing Loss: 1.3505, Testing Accuracy: 0.5176
# Training Iteration 6, Epoch 2/10, Training Loss: 1.2854, Training Accuracy: 0.5449
# Testing Loss: 1.2138, Testing Accuracy: 0.5678
# Training Iteration 6, Epoch 3/10, Training Loss: 1.1934, Training Accuracy: 0.5825
# Testing Loss: 1.1599, Testing Accuracy: 0.5964
# Training Iteration 6, Epoch 4/10, Training Loss: 1.1439, Training Accuracy: 0.5978
# Testing Loss: 1.1452, Testing Accuracy: 0.5983
# Training Iteration 6, Epoch 5/10, Training Loss: 1.1175, Training Accuracy: 0.6075
# Testing Loss: 1.1416, Testing Accuracy: 0.6082
# Training Iteration 6, Epoch 6/10, Training Loss: 1.1002, Training Accuracy: 0.6158
# Testing Loss: 1.1251, Testing Accuracy: 0.6111
# Training Iteration 6, Epoch 7/10, Training Loss: 1.0841, Training Accuracy: 0.6222
# Testing Loss: 1.1546, Testing Accuracy: 0.5963
# Training Iteration 6, Epoch 8/10, Training Loss: 1.0761, Training Accuracy: 0.6251
# Testing Loss: 1.1277, Testing Accuracy: 0.6154
# Training Iteration 6, Epoch 9/10, Training Loss: 1.0641, Training Accuracy: 0.6304
# Testing Loss: 1.1004, Testing Accuracy: 0.6168
# Training Iteration 6, Epoch 10/10, Training Loss: 1.0565, Training Accuracy: 0.6322
# Testing Loss: 1.1073, Testing Accuracy: 0.6211
# Training Iteration 7, Epoch 1/10, Training Loss: 1.5092, Training Accuracy: 0.4535
# Testing Loss: 1.3457, Testing Accuracy: 0.5168
# Training Iteration 7, Epoch 2/10, Training Loss: 1.3047, Training Accuracy: 0.5367
# Testing Loss: 1.2391, Testing Accuracy: 0.5638
# Training Iteration 7, Epoch 3/10, Training Loss: 1.2383, Training Accuracy: 0.5625
# Testing Loss: 1.2732, Testing Accuracy: 0.5461
# Training Iteration 7, Epoch 4/10, Training Loss: 1.1980, Training Accuracy: 0.5797
# Testing Loss: 1.2164, Testing Accuracy: 0.5688
# Training Iteration 7, Epoch 5/10, Training Loss: 1.1656, Training Accuracy: 0.5904
# Testing Loss: 1.1783, Testing Accuracy: 0.5882
# Training Iteration 7, Epoch 6/10, Training Loss: 1.1391, Training Accuracy: 0.6006
# Testing Loss: 1.1425, Testing Accuracy: 0.5977
# Training Iteration 7, Epoch 7/10, Training Loss: 1.1170, Training Accuracy: 0.6107
# Testing Loss: 1.1165, Testing Accuracy: 0.6090
# Training Iteration 7, Epoch 8/10, Training Loss: 1.1030, Training Accuracy: 0.6156
# Testing Loss: 1.1747, Testing Accuracy: 0.5929
# Training Iteration 7, Epoch 9/10, Training Loss: 1.0916, Training Accuracy: 0.6206
# Testing Loss: 1.1148, Testing Accuracy: 0.6118
# Training Iteration 7, Epoch 10/10, Training Loss: 1.0779, Training Accuracy: 0.6256
# Testing Loss: 1.1113, Testing Accuracy: 0.6115
# Training Iteration 8, Epoch 1/10, Training Loss: 1.4933, Training Accuracy: 0.4660
# Testing Loss: 1.3188, Testing Accuracy: 0.5338
# Training Iteration 8, Epoch 2/10, Training Loss: 1.2706, Training Accuracy: 0.5522
# Testing Loss: 1.2915, Testing Accuracy: 0.5415
# Training Iteration 8, Epoch 3/10, Training Loss: 1.2066, Training Accuracy: 0.5760
# Testing Loss: 1.1686, Testing Accuracy: 0.5925
# Training Iteration 8, Epoch 4/10, Training Loss: 1.1668, Training Accuracy: 0.5922
# Testing Loss: 1.1710, Testing Accuracy: 0.5895
# Training Iteration 8, Epoch 5/10, Training Loss: 1.1439, Training Accuracy: 0.6013
# Testing Loss: 1.1389, Testing Accuracy: 0.6080
# Training Iteration 8, Epoch 6/10, Training Loss: 1.1235, Training Accuracy: 0.6100
# Testing Loss: 1.1328, Testing Accuracy: 0.6069
# Training Iteration 8, Epoch 7/10, Training Loss: 1.1117, Training Accuracy: 0.6121
# Testing Loss: 1.1665, Testing Accuracy: 0.6012
# Training Iteration 8, Epoch 8/10, Training Loss: 1.1022, Training Accuracy: 0.6163
# Testing Loss: 1.1151, Testing Accuracy: 0.6093
# Training Iteration 8, Epoch 9/10, Training Loss: 1.0879, Training Accuracy: 0.6233
# Testing Loss: 1.0955, Testing Accuracy: 0.6159
# Training Iteration 8, Epoch 10/10, Training Loss: 1.0825, Training Accuracy: 0.6226
# Testing Loss: 1.1172, Testing Accuracy: 0.6132
# Training Iteration 9, Epoch 1/10, Training Loss: 1.4871, Training Accuracy: 0.4697
# Testing Loss: 1.3651, Testing Accuracy: 0.5196
# Training Iteration 9, Epoch 2/10, Training Loss: 1.2750, Training Accuracy: 0.5526
# Testing Loss: 1.2157, Testing Accuracy: 0.5792
# Training Iteration 9, Epoch 3/10, Training Loss: 1.2095, Training Accuracy: 0.5763
# Testing Loss: 1.2304, Testing Accuracy: 0.5624
# Training Iteration 9, Epoch 4/10, Training Loss: 1.1718, Training Accuracy: 0.5893
# Testing Loss: 1.1989, Testing Accuracy: 0.5842
# Training Iteration 9, Epoch 5/10, Training Loss: 1.1454, Training Accuracy: 0.5983
# Testing Loss: 1.1402, Testing Accuracy: 0.6022
# Training Iteration 9, Epoch 6/10, Training Loss: 1.1309, Training Accuracy: 0.6067
# Testing Loss: 1.1747, Testing Accuracy: 0.5908
# Training Iteration 9, Epoch 7/10, Training Loss: 1.1168, Training Accuracy: 0.6136
# Testing Loss: 1.1665, Testing Accuracy: 0.5989
# Training Iteration 9, Epoch 8/10, Training Loss: 1.1057, Training Accuracy: 0.6133
# Testing Loss: 1.0998, Testing Accuracy: 0.6232
# Training Iteration 9, Epoch 9/10, Training Loss: 1.0986, Training Accuracy: 0.6169
# Testing Loss: 1.0915, Testing Accuracy: 0.6223
# Training Iteration 9, Epoch 10/10, Training Loss: 1.0910, Training Accuracy: 0.6211
# Testing Loss: 1.1044, Testing Accuracy: 0.6135
# Training Iteration 10, Epoch 1/10, Training Loss: 1.4791, Training Accuracy: 0.4705
# Testing Loss: 1.3123, Testing Accuracy: 0.5329
# Training Iteration 10, Epoch 2/10, Training Loss: 1.2715, Training Accuracy: 0.5506
# Testing Loss: 1.2275, Testing Accuracy: 0.5693
# Training Iteration 10, Epoch 3/10, Training Loss: 1.2163, Training Accuracy: 0.5729
# Testing Loss: 1.2199, Testing Accuracy: 0.5723
# Training Iteration 10, Epoch 4/10, Training Loss: 1.1812, Training Accuracy: 0.5863
# Testing Loss: 1.2207, Testing Accuracy: 0.5742
# Training Iteration 10, Epoch 5/10, Training Loss: 1.1568, Training Accuracy: 0.5965
# Testing Loss: 1.1789, Testing Accuracy: 0.5820
# Training Iteration 10, Epoch 6/10, Training Loss: 1.1378, Training Accuracy: 0.6042
# Testing Loss: 1.1681, Testing Accuracy: 0.5917
# Training Iteration 10, Epoch 7/10, Training Loss: 1.1198, Training Accuracy: 0.6098
# Testing Loss: 1.1918, Testing Accuracy: 0.5895
# Training Iteration 10, Epoch 8/10, Training Loss: 1.1078, Training Accuracy: 0.6098
# Testing Loss: 1.2021, Testing Accuracy: 0.5799
# Training Iteration 10, Epoch 9/10, Training Loss: 1.1013, Training Accuracy: 0.6157
# Testing Loss: 1.1580, Testing Accuracy: 0.6016
# Training Iteration 10, Epoch 10/10, Training Loss: 1.0885, Training Accuracy: 0.6221
# Testing Loss: 1.1607, Testing Accuracy: 0.5966
